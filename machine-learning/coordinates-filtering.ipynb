# %%
import folium
import os
import geopandas as gpd
import pandas as pd

from shapely.geometry import Point

# %%
filter_folder = 'shape-filter'
shapefiles = [file for file in os.listdir(filter_folder) if file.endswith('.shp')]
filter_gdf = [gpd.read_file(os.path.join(filter_folder, shp)) for shp in shapefiles]
filter_df = gpd.GeoDataFrame(pd.concat(filter_gdf, ignore_index=True))
filter_df
# Out:
#     AQDATE FCODE  KLSRMP KODATC NAMOBJ PUDATE         REMARK SRS_ID  JNSPDG  \
# 0     None  None     1.0   None   None   None  Padang Rumput   None     1.0
# 1     None  None     1.0   None   None   None  Padang Rumput   None     1.0
# 2     None  None     1.0   None   None   None  Padang Rumput   None     1.0
# 3     None  None     1.0   None   None   None  Padang Rumput   None     1.0
# 4     None  None     1.0   None   None   None  Padang Rumput   None     1.0
# ..     ...   ...     ...    ...    ...    ...            ...    ...     ...
# 714   None  None     NaN    NaN   None   None  Semak Belukar   None     NaN
# 715   None  None     NaN    NaN   None   None  Semak Belukar   None     NaN
# 716   None  None     NaN    NaN   None   None  Semak Belukar   None     NaN
# 717   None  None     NaN    NaN   None   None  Semak Belukar   None     NaN
# 718   None  None     NaN    NaN   None   None  Semak Belukar   None     NaN
#
#       LCODE  ... KRPPHN  KODLCO  KLSLCO KRAPAT  SPSABS  RPTHTN  JNSHTB TKTHTN  \
# 0    FB0020  ...    NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN
# 1    FB0020  ...    NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN
# 2    FB0020  ...    NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN
# 3    FB0020  ...    NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN
# 4    FB0020  ...    NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN
# ..      ...  ...    ...     ...     ...    ...     ...     ...     ...    ...
# 714  FB0040  ...    NaN    None     NaN    NaN     NaN     NaN     NaN    NaN
# 715  FB0040  ...    NaN    None     NaN    NaN     NaN     NaN     NaN    NaN
# 716  FB0040  ...    NaN    None     NaN    NaN     NaN     NaN     NaN    NaN
# 717  FB0040  ...    NaN    None     NaN    NaN     NaN     NaN     NaN    NaN
# 718  FB0040  ...    NaN    None     NaN    NaN     NaN     NaN     NaN    NaN
#
#      TIPHTN  JNSSMK
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ..      ...     ...
# 714     NaN     0.0
# 715     NaN     0.0
# 716     NaN     0.0
# 717     NaN     0.0
# 718     NaN     0.0
#
# [719 rows x 26 columns]

# %%
coordinates = pd.read_csv('coordinates/filtered_land_points.csv')
coordinates = coordinates.filter(items=['lat', 'lon'])
coordinates
# Out:
#            lat         lon
# 0    -8.848272  115.128369
# 1    -8.848272  115.137460
# 2    -8.848272  115.146550
# 3    -8.848271  115.155641
# 4    -8.848271  115.164732
# ...        ...         ...
# 6401 -8.104389  115.294892
# 6402 -8.104389  115.303965
# 6403 -8.104389  115.313038
# 6404 -8.104389  115.322111
# 6405 -8.104388  115.331184
#
# [6406 rows x 2 columns]

# %%
geometry = [Point(xy) for xy in zip(coordinates['lon'], coordinates['lat'])]
points_df = gpd.GeoDataFrame(coordinates, geometry=geometry)
points_df = points_df.set_crs(crs=filter_df.crs, allow_override=True)

# %%
points_inside = gpd.sjoin(points_df, filter_df, how='left', predicate='within')

# %%
points_outside = points_inside[points_inside['index_right'].isna()]
filtered_points = coordinates[coordinates.index.isin(points_outside.index)]

# %%
filtered_points
# Out:
#            lat         lon
# 0    -8.848272  115.128369
# 1    -8.848272  115.137460
# 2    -8.848272  115.146550
# 3    -8.848271  115.155641
# 4    -8.848271  115.164732
# ...        ...         ...
# 6401 -8.104389  115.294892
# 6402 -8.104389  115.303965
# 6403 -8.104389  115.313038
# 6404 -8.104389  115.322111
# 6405 -8.104388  115.331184
#
# [4758 rows x 2 columns]

# %%
forest_filtered = folium.Map(location=[filtered_points['lat'][0], filtered_points['lon'][0]], zoom_start=6)

for lat, lon in filtered_points.values:
    folium.Marker([lat, lon]).add_to(forest_filtered)

forest_filtered.save('map-export/forest_filtered_area.html')
